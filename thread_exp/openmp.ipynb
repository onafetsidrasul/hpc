# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('thread_speedup_2025-09-01_160718.csv')
df
# Out:
#    threads    time  speedup  efficiency  wall_time
# 0        1  222.50     1.00        1.00     222.51
# 1        2  121.91     1.83        0.91     121.93
# 2        4   83.82     2.65        0.66      83.83
# 3        8   66.03     3.37        0.42      66.04
# 4       16   45.37     4.90        0.31      45.39
# 5       32   34.49     6.45        0.20      34.50
# 6       56   32.37     6.87        0.12      32.38
# 7       84   42.10     5.29        0.06      42.11
# 8      112   37.24     5.97        0.05      37.26

# %%
plt.figure(figsize=(8,5))
plt.plot(df['threads'], df['speedup'], marker='o', label='Speedup')
plt.plot(df['threads'], df['threads'], 'k--', label='Ideal linear speedup')
plt.xlabel('threads')
plt.ylabel('Speedup')
plt.title('Speedup')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(df['threads'], df['efficiency'], marker='o', color='orange', label='Efficiency')
plt.xlabel('threads')
plt.ylabel('Efficiency')
plt.title('Efficiency')
plt.grid(True)
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(15,5))
axs[0].plot(df['threads'], df['speedup'], marker='o', label='Speedup')
axs[0].plot(df['threads'], df['threads'], 'k--', label='Ideal linear speedup')
axs[0].set_xlabel('threads')
axs[0].set_ylabel('Speedup')
axs[0].set_title('Speedup')
axs[0].legend()
axs[0].grid(True)

axs[1].plot(df['threads'], df['efficiency'], marker='o', color='orange', label='Efficiency')
axs[1].set_xlabel('threads')
axs[1].set_ylabel('Efficiency')
axs[1].set_title('Efficiency')
axs[1].grid(True)

plt.tight_layout()
plt.show()
